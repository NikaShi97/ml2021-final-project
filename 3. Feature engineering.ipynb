# %%
import pathlib
import numpy as np
import pandas as pd

data = pathlib.Path().absolute() / 'data'

# %%
df = pd.read_csv(data / 'undersampled_shuffled.csv')

# %%
df.sample(7)
# Out:
#          Gamma0_VH  Gamma0_VV  Gamma0_Ratio      B1      B2      B3      B4  \
# 2530108   0.032513   0.169725      5.220223  0.0038  0.0113  0.0242  0.0131
# 1970187   0.055453   0.263226      4.746802  0.0112  0.0201  0.0368  0.0233
# 6365938   0.047672   0.227207      4.766073  0.0037  0.0133  0.0281  0.0156
# 2392503   0.026050   0.152113      5.839338  0.0028  0.0121  0.0260  0.0154
# 444744    0.043319   0.134903      3.114166  0.0073  0.0170  0.0401  0.0207
# 2767598   0.052118   0.157208      3.016408  0.0046  0.0156  0.0323  0.0184
# 6152024   0.037523   0.163368      4.353766  0.0088  0.0156  0.0330  0.0165
#
#              B5      B6      B7      B8      B9     B11     B12   Class
# 2530108  0.0453  0.1717  0.1994  0.2250  0.2377  0.0971  0.0418  spruce
# 1970187  0.0649  0.1668  0.1937  0.2048  0.2285  0.1168  0.0597  swamps
# 6365938  0.0519  0.1449  0.1684  0.1667  0.2028  0.0819  0.0373  spruce
# 2392503  0.0420  0.1193  0.1421  0.1590  0.1418  0.0748  0.0360    pine
# 444744   0.0645  0.1897  0.2245  0.2475  0.2427  0.1007  0.0458    pine
# 2767598  0.0492  0.1686  0.2014  0.2303  0.2323  0.1015  0.0456    pine
# 6152024  0.0618  0.2540  0.3248  0.3294  0.3234  0.1215  0.0512   birch

# %%
df['NDVI'] = (df.B8 - df.B4) / (df.B8 + df.B4)
df['mNDVI'] = (df.B8 - df.B4) / (df.B8 + df.B4 - 2 * df.B1)
df['NGRDI'] = (df.B3 - df.B5) / (df.B3 + df.B5)
df['DVI'] = df.B8 - df.B4
df['S2RVI'] = df.B8 / df.B4
df['GNDVI'] = (df.B8 - df.B3) / (df.B8 + df.B3)
df['IRECI'] = (df.B7 - df.B4) / (df.B5 / df.B6)
df['NDWI'] = (df.B3 - df.B8) / (df.B3 + df.B8)
df['Rededge1'] = df.B5 / df.B4
df['Rededge2'] = (df.B5 - df.B4) / (df.B5 + df.B4)
df['RBNDVI'] = (df.B8 - df.B5 + df.B1) / (df.B8 + df.B5 + df.B1)
df['GRNDVI'] = (df.B8 - df.B3 + df.B1) / (df.B8 + df.B3 + df.B1)
df['GBNDVI'] = (df.B8 - df.B3 + df.B5) / (df.B8 + df.B3 + df.B5)

df['RFDI'] = (df.Gamma0_VV - df.Gamma0_VH) / (df.Gamma0_VV + df.Gamma0_VH)
df['S1RVI'] = 4 * df.Gamma0_VH / (df.Gamma0_VV + 2 * df.Gamma0_VH)
df['Gamma0_VV_db'] = 10 * np.log10(abs(df.Gamma0_VV))
df['Gamma0_VH_db'] = 10 * np.log10(abs(df.Gamma0_VH))
df['Gamma0_Ratio_db'] = 10 * np.log10(abs(df.Gamma0_Ratio))

df.drop(['Gamma0_VV', 'Gamma0_VH', 'Gamma0_Ratio'], axis=1, inplace=True)

# %%
df.iloc[:, 12:].sample(7)
# Out:
#              NDVI     mNDVI     NGRDI     DVI      S2RVI     GNDVI     IRECI  \
# 3433255  0.778121  0.822976 -0.438513  0.4026   8.013937  0.732580  0.697120
# 3594178  0.852885  0.863286 -0.176836  0.2690  12.594828  0.760241  0.685756
# 1363108  0.868132  0.919069 -0.081505  0.1817  14.166667  0.739324  0.399717
# 2335610  0.871886  0.882656 -0.311077  0.1715  14.611111  0.780464  0.480725
# 6526634  0.830524  0.878218 -0.261876  0.1774  10.801105  0.731621  0.436828
# 1960997  0.783843  0.821074 -0.516038  0.3561   8.252546  0.775246  0.568891
# 1537487  0.892126  0.944226 -0.216799  0.2878  17.540230  0.796880  1.113907
#
#              NDWI  Rededge1  Rededge2    RBNDVI    GRNDVI    GBNDVI      RFDI  \
# 3433255 -0.732580  3.168990  0.520267  0.445427  0.739497  0.800814  0.835442
# 3594178 -0.760241  2.452586  0.420724  0.675783  0.761605  0.795320  0.696714
# 1363108 -0.739324  2.500000  0.428571  0.707379  0.745880  0.774007  0.686084
# 2335610 -0.780464  3.428571  0.548387  0.621882  0.781731  0.818400  0.673975
# 6526634 -0.731621  2.861878  0.482117  0.590676  0.738342  0.781700  0.728560
# 1960997 -0.775246  3.272912  0.531935  0.442208  0.780206  0.833765  0.783343
# 1537487 -0.796880  3.080460  0.509859  0.708458  0.802065  0.824561  0.715423
#
#             S1RVI  Gamma0_VV_db  Gamma0_VH_db  Gamma0_Ratio_db
# 3433255  0.304096     -9.040132    -19.514337        10.474205
# 3594178  0.526701     -5.739960    -13.217524         7.477564
# 1363108  0.542658     -9.180831    -16.481486         7.300656
# 2335610  0.560656     -6.975548    -14.080528         7.104980
# 6526634  0.478006     -7.901959    -15.942061         8.040102
# 1960997  0.390962     -9.227263    -18.381878         9.154615
# 1537487  0.498258     -6.530186    -14.331898         7.801712

# %%
df.to_csv(data / 'undersampled_shuffled_new_features.csv', index=False)
